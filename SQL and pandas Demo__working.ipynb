# %% [markdown]
# # SQL and Pandas on databricks for Data Scientists

# %% [markdown]
# ###Explore Single Family Mortgages from the Census Tract Dataset 2010-2015

# %% [markdown]
# [Dataset Reference - https://www.fhfa.gov/DataTools/Downloads/Pages/Public-Use-Databases.aspx](https://www.fhfa.gov/DataTools/Downloads/Pages/Public-Use-Databases.aspx)
#
# [Schema - https://www.fhfa.gov/DataTools/Downloads/Documents/Enterprise-PUDB/Single-Family_Census_Tract_File_/2015_Single_Family_Census_Tract_File.pdf](https://www.fhfa.gov/DataTools/Downloads/Documents/Enterprise-PUDB/Single-Family_Census_Tract_File_/2015_Single_Family_Census_Tract_File.pdf)
#
# ###1. Ingest the Dataset

# %%
df = sqlContext.read.format('csv').option("header", "true").option("delimiter", "\t").option("inferSchema", "true").load("/home/silvio/mortgage_data")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df.describe())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>fannieorfreddie</th><th>record</th><th>usps_code</th><th>msa_code</th><th>county_code</th><th>census_tract</th><th>minority_percent</th><th>census_median_income</th><th>local_median_income</th><th>tract_income_ratio</th><th>borrowers_annual_income</th><th>area_median_family_income</th><th>borrower_income_ratio</th><th>unpaid_balance</th><th>loan_purpose</th><th>federal_guarantee</th><th>number_of_borrowers</th><th>first_time_buyers</th><th>borrower_race_1</th><th>borrower_race_2</th><th>borrower_race_3</th><th>borrower_race_4</th><th>borrower_race_5</th><th>borrower_ethnicity</th><th>co_borrower_race_1</th><th>co_borrower_race_2</th><th>co_borrower_race_3</th><th>co_borrower_race_4</th><th>co_borrower_race_5</th><th>co_borrower_ethnicity</th><th>borrower_gender</th><th>co_borrower_gender</th><th>borrower_age</th><th>co_borrower_age</th><th>occupancy_code</th><th>rate_spread</th><th>hoepa_status</th><th>property_type</th><th>lien_status</th><th>year</th></tr></thead><tbody><tr><td>count</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td></tr><tr><td>mean</td><td>1.0</td><td>1527826.6474815835</td><td>26.349713580389615</td><td>37417.891445221096</td><td>79.59858141608417</td><td>227233.1500790365</td><td>32.60364062413058</td><td>79648.51955186219</td><td>65299.31692772914</td><td>9.96716024317566</td><td>125496.39610362331</td><td>71266.98733175945</td><td>15.436795748739826</td><td>211409.4219233987</td><td>1.7212525776372323</td><td>1.0042655696600042</td><td>1.8592588311601048</td><td>1.9188794976571049</td><td>4.873367322343074</td><td>8.96878849628457</td><td>8.997387460436771</td><td>8.999422704421763</td><td>8.974751021335624</td><td>2.0927048267805732</td><td>6.732621163311227</td><td>8.990364055392059</td><td>8.999129327555387</td><td>8.999677784466183</td><td>8.986113804460837</td><td>5.172269897897191</td><td>1.4120656806743677</td><td>2.870401523610049</td><td>103.0115942467961</td><td>506.43552271622417</td><td>1.0915901571597126</td><td>0.030775626115322655</td><td>1.9999961122923167</td><td>1.0888406194197613</td><td>1.0010139373740194</td><td>2012.304949063486</td></tr><tr><td>stddev</td><td>0.0</td><td>973932.0539615656</td><td>16.870274386483654</td><td>22996.78557760105</td><td>91.66069721015857</td><td>312855.4239868818</td><td>242.533562427931</td><td>41676.329294231065</td><td>30821.96112820461</td><td>295.52504671039435</td><td>383407.3056314145</td><td>24706.402407338246</td><td>371.6661442773271</td><td>119781.21084474263</td><td>0.5082840774485791</td><td>0.09043433942544522</td><td>5.440379817992817</td><td>0.5010964121864502</td><td>1.0966061411366639</td><td>0.3957855836070374</td><td>0.12303352217716507</td><td>0.052476000396396015</td><td>0.32609409097420305</td><td>0.710532873847303</td><td>2.171317353530967</td><td>0.23338143286804724</td><td>0.07056318912056861</td><td>0.03864622032709379</td><td>0.24215320482976876</td><td>3.460284076944615</td><td>0.7615375054073371</td><td>1.1408644827428915</td><td>222.19078139301308</td><td>475.46112511142474</td><td>0.2884465376789499</td><td>0.3066089878737382</td><td>0.0019717233058138845</td><td>0.8207539501561228</td><td>0.03182623703480405</td><td>1.5846875442585984</td></tr><tr><td>min</td><td>1 ...

# %% [markdown]
# ## Cache datasets that you will be doing frequent operations on in order to massively speed up queries.

# %%
df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">3</span><span class="ansired">]: </span>17233806
# </div>

# %%
df.cache().count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">4</span><span class="ansired">]: </span>17233806
# </div>

# %%
df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">5</span><span class="ansired">]: </span>17233806
# </div>

# %%
display(df.describe())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>fannieorfreddie</th><th>record</th><th>usps_code</th><th>msa_code</th><th>county_code</th><th>census_tract</th><th>minority_percent</th><th>census_median_income</th><th>local_median_income</th><th>tract_income_ratio</th><th>borrowers_annual_income</th><th>area_median_family_income</th><th>borrower_income_ratio</th><th>unpaid_balance</th><th>loan_purpose</th><th>federal_guarantee</th><th>number_of_borrowers</th><th>first_time_buyers</th><th>borrower_race_1</th><th>borrower_race_2</th><th>borrower_race_3</th><th>borrower_race_4</th><th>borrower_race_5</th><th>borrower_ethnicity</th><th>co_borrower_race_1</th><th>co_borrower_race_2</th><th>co_borrower_race_3</th><th>co_borrower_race_4</th><th>co_borrower_race_5</th><th>co_borrower_ethnicity</th><th>borrower_gender</th><th>co_borrower_gender</th><th>borrower_age</th><th>co_borrower_age</th><th>occupancy_code</th><th>rate_spread</th><th>hoepa_status</th><th>property_type</th><th>lien_status</th><th>year</th></tr></thead><tbody><tr><td>count</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td><td>17233806</td></tr><tr><td>mean</td><td>1.0</td><td>1527826.6474815835</td><td>26.349713580389615</td><td>37417.891445221096</td><td>79.59858141608417</td><td>227233.1500790365</td><td>32.60364062413058</td><td>79648.51955186219</td><td>65299.31692772914</td><td>9.96716024317566</td><td>125496.39610362331</td><td>71266.98733175945</td><td>15.436795748739826</td><td>211409.4219233987</td><td>1.7212525776372323</td><td>1.0042655696600042</td><td>1.8592588311601048</td><td>1.9188794976571049</td><td>4.873367322343074</td><td>8.96878849628457</td><td>8.997387460436771</td><td>8.999422704421763</td><td>8.974751021335624</td><td>2.0927048267805732</td><td>6.732621163311227</td><td>8.990364055392059</td><td>8.999129327555387</td><td>8.999677784466183</td><td>8.986113804460837</td><td>5.172269897897191</td><td>1.4120656806743677</td><td>2.870401523610049</td><td>103.0115942467961</td><td>506.43552271622417</td><td>1.0915901571597126</td><td>0.030775626115322655</td><td>1.9999961122923167</td><td>1.0888406194197613</td><td>1.0010139373740194</td><td>2012.304949063486</td></tr><tr><td>stddev</td><td>0.0</td><td>973932.0539615656</td><td>16.870274386483654</td><td>22996.78557760105</td><td>91.66069721015857</td><td>312855.4239868818</td><td>242.533562427931</td><td>41676.329294231065</td><td>30821.96112820461</td><td>295.52504671039435</td><td>383407.3056314145</td><td>24706.402407338246</td><td>371.6661442773271</td><td>119781.21084474263</td><td>0.5082840774485791</td><td>0.09043433942544522</td><td>5.440379817992817</td><td>0.5010964121864502</td><td>1.0966061411366639</td><td>0.3957855836070374</td><td>0.12303352217716507</td><td>0.052476000396396015</td><td>0.32609409097420305</td><td>0.710532873847303</td><td>2.171317353530967</td><td>0.23338143286804724</td><td>0.07056318912056861</td><td>0.03864622032709379</td><td>0.24215320482976876</td><td>3.460284076944615</td><td>0.7615375054073371</td><td>1.1408644827428915</td><td>222.19078139301308</td><td>475.46112511142474</td><td>0.2884465376789499</td><td>0.3066089878737382</td><td>0.0019717233058138845</td><td>0.8207539501561228</td><td>0.03182623703480405</td><td>1.5846875442585984</td></tr><tr><td>min</td><td>1 ...

# %% [markdown]
# ###2. Explore the Dataset Using PySpark

# %%
df.createOrReplaceTempView("mortgages")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql select year, avg(unpaid_balance) from mortgages group by year order by year asc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>year</th><th>avg(unpaid_balance)</th></tr></thead><tbody><tr><td>2010</td><td>219642.78137108506</td></tr><tr><td>2011</td><td>208898.01220857457</td></tr><tr><td>2012</td><td>213157.70954362722</td></tr><tr><td>2013</td><td>204563.08591091988</td></tr><tr><td>2014</td><td>201935.24813276</td></tr><tr><td>2015</td><td>220038.7608634289</td></tr></tbody></table></div>

# %%
from pyspark.sql.types import *
from pyspark.sql import functions as f

display(table("mortgages").groupBy("year").agg(f.avg("unpaid_balance")).orderBy("year"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>year</th><th>avg(unpaid_balance)</th></tr></thead><tbody><tr><td>2010</td><td>219642.78137108506</td></tr><tr><td>2011</td><td>208898.01220857457</td></tr><tr><td>2012</td><td>213157.70954362722</td></tr><tr><td>2013</td><td>204563.08591091988</td></tr><tr><td>2014</td><td>201935.24813276</td></tr><tr><td>2015</td><td>220038.7608634289</td></tr></tbody></table></div>

# %% [markdown]
# You can access spark tables either using `table` or `sql` commands in pyspark

# %% [markdown]
# You can make a permanent table using `dataframe.write.saveAsTable('<example-table>')`. See [tables guide](https://docs.databricks.com/user-guide/tables.html) for more info.

# %% [markdown]
# # Writing to pandas

# %% [markdown]
# running `df.toPandas()` will send all the data from the cluster to a single node. Sending the data can take a long time, and if the data is larger than a single node the task will fail with an out of memory error (OOM).

# %%
df = spark.table("mortgages")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>fannieorfreddie</th><th>record</th><th>usps_code</th><th>msa_code</th><th>county_code</th><th>census_tract</th><th>minority_percent</th><th>census_median_income</th><th>local_median_income</th><th>tract_income_ratio</th><th>borrowers_annual_income</th><th>area_median_family_income</th><th>borrower_income_ratio</th><th>unpaid_balance</th><th>loan_purpose</th><th>federal_guarantee</th><th>number_of_borrowers</th><th>first_time_buyers</th><th>borrower_race_1</th><th>borrower_race_2</th><th>borrower_race_3</th><th>borrower_race_4</th><th>borrower_race_5</th><th>borrower_ethnicity</th><th>co_borrower_race_1</th><th>co_borrower_race_2</th><th>co_borrower_race_3</th><th>co_borrower_race_4</th><th>co_borrower_race_5</th><th>co_borrower_ethnicity</th><th>borrower_gender</th><th>co_borrower_gender</th><th>borrower_age</th><th>co_borrower_age</th><th>occupancy_code</th><th>rate_spread</th><th>hoepa_status</th><th>property_type</th><th>lien_status</th><th>year</th></tr></thead><tbody><tr><td>1</td><td>2581112</td><td>6</td><td>41940</td><td>85</td><td>508507</td><td>79.71</td><td>92600</td><td>99794</td><td>0.9279</td><td>92000</td><td>105000</td><td>0.8762</td><td>335000</td><td>2</td><td>1</td><td>1</td><td>2</td><td>2</td><td>9</td><td>9</td><td>9</td><td>9</td><td>2</td><td>9</td><td>9</td><td>9</td><td>9</td><td>9</td><td>9</td><td>2</td><td>4</td><td>53</td><td>999</td><td>1</td><td>0.0</td><td>2</td><td>1</td><td>1</td><td>2012</td></tr><tr><td>1</td><td>2581113</td><td>55</td><td>33340</td><td>89</td><td>630202</td><td>8.42</td><td>72356</td><td>68787</td><td>1.0519</td><td>67000</td><td>73200</td><td>0.9153</td><td>185000</td><td>2</td><td>1</td><td>2</td><td>2</td><td>5</td><td>9</td><td>9</td><td>9</td><td>9</td><td>2</td><td>5</td><td>9</td><td>9</td><td>9</td><td>9</td><td>2</td><td>1</td><td>2</td><td>31</td><td>27</td><td>1</td><td>0.0</td><td>2</td><td>1</td><td>1</td><td>2012</td></tr><tr><td>1</td><td>2581114</td><td>55</td><td>33340</td><td>131</td><td>420104</td><td>4.45</td><td>71458</td><td>68787</td><td>1.0388</td><td>33000</td><td>73200</td><td>0.4508</td><td>177000</td><td>2</td><td>1</td><td>2</td><td>2</td><td>5</td><td>9</td><td>9</td><td>9</td><td>9</td><td>2</td><td>5</td><td>9</td><td>9</td><td>9</td><td>9</td><td>2</td><td>1</td><td>2</td><td>62</td><td>50</td><td>1</td><td>0.0</td><td>2</td><td>1</td><td>1</td><td>2012</td></tr><tr><td>1</td><td>2581115</td><td>55</td><td>11540</td><td>87</td><td>12901</td><td>3.48</td><td>76875</td><td>69972</td><td>1.0987</td><td>87000</td><td>73600</td><td>1.1821</td><td>154000</td><td>2</td><td>1</td><td>2</td><td>2</td><td>5</td><td>9</td><td>9</td><td>9</td><td>9</td><td>2</td><td>5</td><td>9</td><td>9</td><td>9</td><td>9</td><td>2</td><td>1</td><td>2</td><td>43</td><td>48</td><td>1</td><td>0.0</td><td>2</td><td>1</td><td>1</td><td>2012</td></tr><tr><td>1</td><td>2581116</td><td>37</td><td>49180</td><td>67</td><td>3201</td><td>20.84</td><td>70298</td><td>57577</td><td>1.2209</td><td>191000</td><td>62000</td><td>3.0806</td><td>201000</td><td>1</td><td>1</td><td>2</td><td>2</td><td>5</td><td>9</td><td>9</td><td>9</td><td>9</td><td>2</td><td>5</td><td>9</td><td>9</td><td>9</td><td>9</td><td>2</td><td>1</td><td>2</td><td>32</td><td>28</td><td>1</td><td>0.0</td><td>2</td><td>1</td><td>1</td><td>2012</td></tr><tr><td>1</td><td>2581117</td><td>48</td><td>26420</td><td>201</td><td>412600</td><td>21.78</td><td>182540</td><td>64179</td><td>2.8442</td><td>201000</td><td>66900</td><td>3.0045</td><td>396000</td><td>2</td><td>1</td><td>2</td><td>2</td><td>5</td><td>9</td><td>9</td><td>9</td><td>9</td><td>2</td><td>5</td><td>9</td><td>9</td><td>9</td><td>9</td><td>2</td><td>1</td><td>2</td><td>41</td><td>40</td><td>1</td><td>0.0</td><td>2</td><td>1</td><td>1</td><td>2012</td></tr><tr><td>1</td><td>2581118</td><td>12</td><td>45300</td><td>103</td><td>26102</td><td>1 ...

# %%
spark.conf.set("spark.sql.execution.arrow.enabled", "false")

#pandas_df = df.toPandas() # This causes an OOM 
pandas_df = spark.sql('SELECT * FROM mortgages LIMIT 1000000').toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark.conf.set("spark.sql.execution.arrow.enabled", "true")

pandas_df = spark.sql('SELECT * FROM mortgages').toPandas() # We just wrote out 17x the data in less than half the time!
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Apache arrow deep dive

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import col, count, rand, collect_list, explode, struct, count
from pyspark.sql.functions import pandas_udf
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = spark.range(0, 10 * 1000 * 1000).withColumn('id', (col('id') / 1000).cast('integer')).withColumn('v', rand())

df.cache()
df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">8</span><span class="ansired">]: </span>10000000
# </div>

# %%
spark.conf.set("spark.sql.execution.arrow.enabled", "false")

# %timeit -n1 -r1 df.toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">1 loops, best of 1: 29.9 s per loop
# </div>

# %%
spark.conf.set("spark.sql.execution.arrow.enabled", "true")

# %timeit -n1 -r1 df.toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">1 loops, best of 1: 451 ms per loop
# </div>

# %% [markdown]
# ## Pandas Vectorized UDFs
#
# https://databricks.com/blog/2017/10/30/introducing-vectorized-udfs-for-pyspark.html

# %% [markdown]
# ### Plus one

# %% [markdown]
# ### Pyspark UDF

# %%
@udf("double")
def plus_one(v):
    return v + 1

# %timeit -n1 -r1 df.withColumn('v', plus_one(df.v)).agg(count(col('v'))).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+
# count(v)|
# +--------+
# 10000000|
# +--------+
#
# 1 loops, best of 1: 1.83 s per loop
# </div>

# %% [markdown]
# ### Pandas vectorized UDF

# %%
@pandas_udf('double')
def vectorized_plus_one(v):
    return v + 1

# %timeit -n1 -r1 df.select('v', vectorized_plus_one(df.v)).agg(count(col('v'))).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+
# count(v)|
# +--------+
# 10000000|
# +--------+
#
# 1 loops, best of 1: 256 ms per loop
# </div>

# %% [markdown]
# ## Calculating CDF

# %% [markdown]
# #### PySpark UDF

# %%
import pandas as pd
from scipy import stats

@udf('double')
def cdf(v):
    return float(stats.norm.cdf(v))

# %timeit -n1 -r1 df.withColumn('cumulative_probability', cdf(df.v)).agg(count(col('cumulative_probability'))).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------------------+
# count(cumulative_probability)|
# +-----------------------------+
#                      10000000|
# +-----------------------------+
#
# 1 loops, best of 1: 32.8 s per loop
# </div>

# %% [markdown]
# ### Pandas Vectorized UDF

# %%
import pandas as pd
from scipy import stats

@pandas_udf('double')
def vectorized_cdf(v):
    return pd.Series(stats.norm.cdf(v))


# %timeit -n1 -r1 df.withColumn('cumulative_probability', vectorized_cdf(df.v)).agg(count(col('cumulative_probability'))).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------------------+
# count(cumulative_probability)|
# +-----------------------------+
#                      10000000|
# +-----------------------------+
#
# 1 loops, best of 1: 1.38 s per loop
# </div>

# %% [markdown]
# ### Computing Subtract mean

# %% [markdown]
# ### PySpark UDF

# %%
from pyspark.sql import Row
@udf(ArrayType(df.schema))
def substract_mean(rows):
    vs = pd.Series([r.v for r in rows])
    vs = vs - vs.mean()
    return [Row(id=rows[i]['id'], v=float(vs[i])) for i in range(len(rows))]
  
# %timeit -n1 -r1 df.groupby('id').agg(collect_list(struct(df['id'], df['v'])).alias('rows')).withColumn('new_rows', substract_mean(col('rows'))).withColumn('new_row', explode(col('new_rows'))).withColumn('id', col('new_row.id')).withColumn('v', col('new_row.v')).agg(count(col('v'))).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+
# count(v)|
# +--------+
# 10000000|
# +--------+
#
# 1 loops, best of 1: 19.4 s per loop
# </div>

# %% [markdown]
# ### Vectorized UDF

# %%
from pyspark.sql.functions import PandasUDFType

@pandas_udf(df.schema, PandasUDFType.GROUPED_MAP)
def vectorized_subtract_mean(pdf):
	return pdf.assign(v=pdf.v - pdf.v.mean())

# %timeit -n1 -r1 df.groupby('id').apply(vectorized_subtract_mean).agg(count(col('v'))).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+
# count(v)|
# +--------+
# 10000000|
# +--------+
#
# 1 loops, best of 1: 3.1 s per loop
# </div>

# %% [markdown]
# # 4. Apply ML to the dataset

# %% [markdown]
# * [spark-scikit learn](https://databricks.com/blog/2016/02/08/auto-scaling-scikit-learn-with-apache-spark.html) for distributed hyperparameter search.
# * [Horovod](https://docs.databricks.com/applications/deep-learning/distributed-deep-learning/index.html) for distributed deep learning.
