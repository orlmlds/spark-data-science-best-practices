# %% [markdown]
# #Identifying Suspicious Behavior in Security Footage
#
# ![image](/files/mnt/raela/video_splash.png)

# %%
# %run ./display_vid

# %% [markdown]
# ## Load training data

# %%
# Read in label data
labels_df = spark.read.parquet("/mnt/raela/cctv_labels2/")

# Join with training dataset
featureDF = spark.read.parquet("/mnt/raela/cctv_features")
train = featureDF.join(labels_df, featureDF.filePath == labels_df.filePath).select("features", "label", featureDF.filePath)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Train LogisticRegression model

# %%
from pyspark.ml.classification import LogisticRegression

# Fit LogisticRegression Model
lr = LogisticRegression(maxIter=20, regParam=0.05, elasticNetParam=0.3, labelCol="label")
lrModel = lr.fit(train)

# Persist lrModel
# lrModel.save("/mnt/raela/suspiciousModel/")

# %% [markdown]
# ## Generate Predictions on Test data

# %%
from pyspark.ml.classification import LogisticRegression, LogisticRegressionModel

# Load Persisted lrModel
lrModel = LogisticRegressionModel.load("/mnt/raela/suspiciousModel/")

# Load Test Data
featuresTestDF = spark.read.parquet("/mnt/raela/cctv_features_test/")

# Generate predictions on test data
result = lrModel.transform(featuresTestDF)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Any suspicious activity in our videos?

# %%
display(result.select("filePath", "probability", "prediction").where("prediction==1"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>filePath</th><th>probability</th><th>prediction</th></tr></thead><tbody><tr><td>dbfs:/mnt/raela/cctvFrames_test/LeftBag_AtChairframe0020.jpg</td><td>List(1, 2, List(), List(0.40104484601382084, 0.5989551539861792))</td><td>1.0</td></tr><tr><td>dbfs:/mnt/raela/cctvFrames_test/LeftBag_AtChairframe0021.jpg</td><td>List(1, 2, List(), List(0.24366344486965386, 0.7563365551303461))</td><td>1.0</td></tr><tr><td>dbfs:/mnt/raela/cctvFrames_test/LeftBag_AtChairframe0022.jpg</td><td>List(1, 2, List(), List(0.4208804442496438, 0.5791195557503561))</td><td>1.0</td></tr><tr><td>dbfs:/mnt/raela/cctvFrames_test/LeftBag_AtChairframe0023.jpg</td><td>List(1, 2, List(), List(0.32215595756323223, 0.6778440424367679))</td><td>1.0</td></tr><tr><td>dbfs:/mnt/raela/cctvFrames_test/LeftBag_AtChairframe0024.jpg</td><td>List(1, 2, List(), List(0.4487986487066727, 0.5512013512933274))</td><td>1.0</td></tr><tr><td>dbfs:/mnt/raela/cctvFrames_test/LeftBag_AtChairframe0025.jpg</td><td>List(1, 2, List(), List(0.3287163850811396, 0.6712836149188603))</td><td>1.0</td></tr><tr><td>dbfs:/mnt/raela/cctvFrames_test/LeftBag_AtChairframe0026.jpg</td><td>List(1, 2, List(), List(0.4333300667042447, 0.5666699332957553))</td><td>1.0</td></tr><tr><td>dbfs:/mnt/raela/cctvFrames_test/LeftBag_AtChairframe0027.jpg</td><td>List(1, 2, List(), List(0.25979194199856254, 0.7402080580014374))</td><td>1.0</td></tr><tr><td>dbfs:/mnt/raela/cctvFrames_test/LeftBag_AtChairframe0028.jpg</td><td>List(1, 2, List(), List(0.3812629523456015, 0.6187370476543985))</td><td>1.0</td></tr><tr><td>dbfs:/mnt/raela/cctvFrames_test/LeftBag_AtChairframe0029.jpg</td><td>List(1, 2, List(), List(0.39069029889387974, 0.6093097011061203))</td><td>1.0</td></tr><tr><td>dbfs:/mnt/raela/cctvFrames_test/LeftBag_AtChairframe0031.jpg</td><td>List(1, 2, List(), List(0.1586159237401691, 0.8413840762598309))</td><td>1.0</td></tr><tr><td>dbfs:/mnt/raela/cctvFrames_test/LeftBag_AtChairframe0032.jpg</td><td>List(1, 2, List(), List(0.34260230736906655, 0.6573976926309334))</td><td>1.0</td></tr><tr><td>dbfs:/mnt/raela/cctvFrames_test/LeftBag_AtChairframe0033.jpg</td><td>List(1, 2, List(), List(0.32489317850744864, 0.6751068214925513))</td><td>1.0</td></tr><tr><td>dbfs:/mnt/raela/cctvFrames_test/LeftBag_AtChairframe0034.jpg</td><td>List(1, 2, List(), List(0.23901543062243538, 0.7609845693775646))</td><td>1.0</td></tr><tr><td>dbfs:/mnt/raela/cctvFrames_test/LeftBag_AtChairframe0035.jpg</td><td>List(1, 2, List(), List(0.39317933053561743, 0.6068206694643825))</td><td>1.0</td></tr><tr><td>dbfs:/mnt/raela/cctvFrames_test/LeftBag_BehindChairframe0010.jpg</td><td>List(1, 2, List(), List(0.4813532777530831, 0.5186467222469169))</td><td>1.0</td></tr><tr><td>dbfs:/mnt/raela/cctvFrames_test/LeftBag_BehindChairframe0036.jpg</td><td>List(1, 2, List(), List(0.38175547603627874, 0.6182445239637213))</td><td>1.0</td></tr><tr><td>dbfs:/mnt/raela/cctvFrames_test/LeftBoxframe0024.jpg</td><td>List(1, 2, List(), List(0.39456778852292845, 0.6054322114770716))</td><td>1.0</td></tr><tr><td>dbfs:/mnt/raela/cctvFrames_test/LeftBoxframe0025.jpg</td><td>List(1, 2, List(), List(0.3142511591189176, 0.6857488408810825))</td><td>1.0</td></tr><tr><td>dbfs:/mnt/raela/cctvFrames_test/LeftBoxframe0026.jpg</td><td>List(1, 2, List(), List(0.42149420761780465, 0.5785057923821955))</td><td>1.0</td></tr><tr><td>dbfs:/mnt/raela/cctvFrames_test/LeftBoxframe0027.jpg</td><td>List(1, 2, List(), List(0.19184616547250857, 0.8081538345274915))</td><td>1.0</td></tr><tr><td>dbfs:/mnt/raela/cctvFrames_test/LeftBoxframe0028.jpg</td><td>List(1, 2, List(), List(0.2767970571573436, 0.7232029428426564))</td><td>1.0</td></tr><tr><td>dbfs:/mnt/raela/cctvFrames_test/LeftBoxframe0029.jpg</td><td>List(1, 2, List(), List(0.3015098750631531, 0.6984901249368469))</td><td>1.0</td></tr><tr><td>dbfs:/mnt/raela/cctvFrames_test/LeftBoxframe0030.jpg</td><td>List(1, 2, List(), ...

# %%
displayImg("dbfs:/mnt/raela/cctvFrames_test/LeftBag_AtChairframe0023.jpg")
# Out:
#   <img src="/files/dbfs:/mnt/raela/cctvFrames_test/LeftBag_AtChairframe0023.jpg">

# %%
displayVid("/mnt/raela/cctvVideos/test/mp4/Fight_OneManDown.mp4")
# Out:
#   <video width="480" height="320" controls>
#   <source src="/files//mnt/raela/cctvVideos/test/mp4/Fight_OneManDown.mp4" type="video/mp4">
#   </video>
